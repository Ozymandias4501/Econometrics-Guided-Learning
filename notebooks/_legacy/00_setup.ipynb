# %% [markdown]
# # Setup and Overview
#
# This tutorial is designed to be hands-on. Most code cells are incomplete on purpose. You will fill them in and run them step by step. The goal is to learn by doing, not by reading outputs.

# %% [markdown]
# ## What You Will Build
# - A pipeline that fetches economic indicators from the FRED API.
# - A feature table for modeling inflation.
# - Regression and classification models with interpretation.

# %% [markdown]
# ## How To Use These Notebooks
# - Read the markdown first.
# - Stop at each TODO and write code.
# - Use Codex for hints if you get stuck.
# - Do not run the whole notebook top-to-bottom without editing.

# %% [markdown]
# ## Concepts You Will See
# - Time-series data and frequency alignment
# - Train/test splits without leakage
# - Linear models, regularization, and interpretation

# %% [markdown]
# ## Your Turn: Project Paths

# %%
from pathlib import Path
import sys

# TODO: Set PROJECT_ROOT to the repo root.
# Hint: notebooks/ is one level below the repo root.
PROJECT_ROOT = ...

# TODO: Define data directories.
DATA_DIR = ...
RAW_DIR = ...
PROCESSED_DIR = ...
SAMPLE_DIR = ...

# TODO: Add PROJECT_ROOT to sys.path so `import src` works.
# Hint: use sys.path.append(str(PROJECT_ROOT)) if not present.
...

PROJECT_ROOT, DATA_DIR

# %% [markdown]
# ## Your Turn: Check FRED API Key

# %%
import os

# TODO: Read FRED_API_KEY from the environment.
# Print a friendly message if it is missing.
api_key = ...

if api_key:
    print('FRED_API_KEY is set.')
else:
    print('FRED_API_KEY is not set. You can still use sample data.')

# %% [markdown]
# ## Optional Practice: Read Sample Data
# If you do not have a key yet, practice on the sample dataset.

# %%
import pandas as pd

# TODO: Load the sample CSV from data/sample/sample_indicators.csv
# Use index_col=0 and parse_dates=True.
sample_path = ...
sample_df = ...

sample_df.head()

# %% [markdown]
# ## Next
# Proceed to `01_fred_api.ipynb` to fetch and cache indicator data from FRED.
