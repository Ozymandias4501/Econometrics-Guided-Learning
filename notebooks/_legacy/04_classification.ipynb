# %% [markdown]
# # Classification Modeling (Hands-On)
#
# You will train a logistic regression model to classify whether inflation is positive next month.

# %% [markdown]
# ## Metrics Refresher
# - Accuracy: overall correctness.
# - Precision: how many predicted ups were actually up.
# - Recall: how many actual ups you caught.
# - ROC-AUC: ranking quality across thresholds.

# %% [markdown]
# ## Your Turn: Setup

# %%
# TODO: Paste your setup code from 00_setup here.
...

# %% [markdown]
# ## Load Features

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, roc_curve

from src import data as data_utils
from src import models
from src import plots

# TODO: Load data/processed/features.csv
features_df = ...

# %% [markdown]
# ## Train/Test Split

# %%
# TODO: Choose the classification target and feature columns.
# target = 'target_inflation_up'

...

# TODO: Split into train/test using time-based split.
...

# %% [markdown]
# ## Logistic Regression

# %%
# TODO: Train logistic regression with scaling.
# Compute probabilities and predictions at threshold 0.5.

...

# TODO: Evaluate with models.evaluate_classification
...

# %% [markdown]
# ## Confusion Matrix and ROC

# %%
# TODO: Build confusion matrix and ROC curve.
# Use plots.plot_confusion_matrix and plots.plot_roc_curve.

...

# %% [markdown]
# ## Try This
# - Change the threshold to 0.4 and 0.6.
# - Compare precision vs recall for each threshold.
