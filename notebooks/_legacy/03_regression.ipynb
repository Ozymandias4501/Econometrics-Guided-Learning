# %% [markdown]
# # Regression Modeling (Hands-On)
#
# You will train linear regression, ridge, and lasso models to predict next-month inflation.

# %% [markdown]
# ## Metrics Refresher
# - MAE: average absolute error (easy to interpret).
# - RMSE: penalizes large errors.
# - R2: proportion of variance explained.

# %% [markdown]
# ## Your Turn: Setup

# %%
# TODO: Paste your setup code from 00_setup here.
...

# %% [markdown]
# ## Load Features

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge, Lasso

from src import data as data_utils
from src import models

# TODO: Load data/processed/features.csv
features_df = ...

features_df.head()

# %% [markdown]
# ## Train/Test Split

# %%
# TODO: Choose the regression target and feature columns.
# target = 'target_cpi_inflation'

...

# TODO: Convert to numpy arrays and run time-based split.
# split = models.time_train_test_split(x, y, test_size=0.2)

# %% [markdown]
# ## Baseline Linear Regression

# %%
# TODO: Train linear regression and evaluate.
# Use models.train_linear_regression and models.evaluate_regression.

...

# %% [markdown]
# ## Ridge and Lasso (with Scaling)

# %%
# TODO: Train ridge and lasso with a StandardScaler pipeline.
# Compare metrics to the baseline.

...

# %% [markdown]
# ## Reflection
# - Which model performs best?
# - Does regularization help or hurt? Why?
