# %% [markdown]
# # Tuning and Interpretation (Deep Dive)
#
# In this notebook you will tune hyperparameters, interpret coefficients, and analyze errors.

# %% [markdown]
# ## Why Tuning Matters
# Regularization controls model complexity. Too little regularization can overfit. Too much can underfit. We will explore this tradeoff.

# %% [markdown]
# ## Your Turn: Setup

# %%
# TODO: Paste your setup code from 00_setup here.
...

# %% [markdown]
# ## Load Features

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge, Lasso, LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.inspection import permutation_importance

from src import data as data_utils
from src import models
from src import plots

# TODO: Load data/processed/features.csv
features_df = ...

# %% [markdown]
# ## Prepare Data

# %%
# TODO: Define regression and classification targets and feature columns.
# Then create time-based splits for each.

...

# %% [markdown]
# ## Ridge Tuning

# %%
# TODO: Loop over a list of alphas and record regression metrics.
# Store results in a dict or DataFrame.

...

# %% [markdown]
# ## Lasso Tuning

# %%
# TODO: Repeat for Lasso.

...

# %% [markdown]
# ## Logistic Regression Tuning

# %%
# TODO: Tune C values and report classification metrics.

...

# %% [markdown]
# ## Coefficient Interpretation

# %%
# TODO: Fit a Ridge model and build a table of feature coefficients.
# Sort by absolute magnitude to see most influential features.

...

# %% [markdown]
# ## Permutation Importance

# %%
# TODO: Run permutation_importance on your regression model.
# Report the top 10 features.

...

# %% [markdown]
# ## Error Analysis

# %%
# TODO: Plot residuals and inspect the largest errors.
# Which dates are the worst? What might explain them?

...

# %% [markdown]
# ## Reflection
# - Which features consistently matter?
# - Do coefficient signs make economic sense?
# - How would you improve the model if you had more data?
